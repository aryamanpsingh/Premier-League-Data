# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lfc = pd.read_csv("Teams/Liverpool.csv")
thfc = pd.read_csv("Teams/Tottenham Hotspur.csv")

# %%
lfc
# Out:
#                        Name Nationality Position       Team   Age  Apps  \
# 0                   Alisson          br       GK  Liverpool  25.0    38
# 1           Virgil van Dijk          nl       DF  Liverpool  27.0    38
# 2             Mohamed Salah          eg    MF,FW  Liverpool  26.0    38
# 3          Andrew Robertson         sco       DF  Liverpool  24.0    36
# 4                Sadio Mané          sn    FW,MF  Liverpool  26.0    36
# 5       Georginio Wijnaldum          nl       MF  Liverpool  27.0    35
# 6           Roberto Firmino          br    FW,MF  Liverpool  26.0    34
# 7    Trent Alexander-Arnold         eng    DF,MF  Liverpool  19.0    29
# 8                   Fabinho          py       DF  Liverpool  24.0    28
# 9          Jordan Henderson          pt       MF  Liverpool  28.0    32
# 10             James Milner         eng       MF  Liverpool  32.0    31
# 11               Joël Matip          es    DF,MF  Liverpool  26.0    22
# ...

# %%
thfc
# Out:
#                       Name Nationality Position               Team   Age  \
# 0              Hugo Lloris          fr       GK  Tottenham Hotspur  31.0
# 1        Toby Alderweireld          be       DF  Tottenham Hotspur  29.0
# 2        Christian Eriksen          dk    DF,MF  Tottenham Hotspur  26.0
# 3               Harry Kane         eng       FW  Tottenham Hotspur  25.0
# 4           Moussa Sissoko          fr       MF  Tottenham Hotspur  28.0
# 5          Kieran Trippier         eng       DF  Tottenham Hotspur  27.0
# 6              Lucas Moura          br    FW,MF  Tottenham Hotspur  25.0
# 7            Son Heung-min          us    MF,FW  Tottenham Hotspur  26.0
# 8         Davinson Sánchez          ie       DF  Tottenham Hotspur  22.0
# 9           Jan Vertonghen          jm       DF  Tottenham Hotspur  31.0
# 10              Ben Davies          ch       DF  Tottenham Hotspur  25.0
# 11               Dele Alli          fr       MF  Tottenham Hotspur  22.0
# ...

# %%
lfc = lfc.drop(['Unnamed: 0'],axis=1)
thfc = thfc.drop(['Unnamed: 0'],axis=1)

# %%
pl_results = pd.read_csv('pl-results-13-19.csv')

# %%
pl_results = pl_results.drop(['Unnamed: 0'],axis=1)

# %%
pl_results.head()
# Out:
#     AC    AF   AR    AS  AST   AY    AwayTeam  B365A  B365D  B365H  ...   \
# 0  0.0   8.0  0.0   3.0  2.0  0.0  Sunderland   8.50   4.50   1.40  ...
# 1  3.0  11.0  0.0   4.0  2.0  0.0     Norwich   4.50   3.60   1.80  ...
# 2  5.0   8.0  0.0  12.0  6.0  2.0   Tottenham   2.75   3.40   2.50  ...
# 3  3.0  14.0  0.0  12.0  8.0  2.0     Swansea   3.80   3.40   2.00  ...
# 4  3.0  14.0  1.0   6.0  3.0  4.0       Stoke   3.10   3.25   2.38  ...
#
#       Referee  SJA  SJD   SJH   VCA   VCD   VCH  WHA  WHD   WHH
# 0       C Foy  9.5  4.5  1.36  8.50  4.75  1.44  8.0  4.0  1.44
# 1    M Oliver  4.5  3.6  1.80  4.75  3.75  1.83  4.5  3.3  1.85
# 2  M Atkinson  2.8  3.4  2.50  2.75  3.40  2.62  2.8  3.0  2.70
# 3   L Probert  3.6  3.3  2.10  4.00  3.50  2.00  3.8  3.3  2.00
# 4    K Friend  3.0  3.2  2.40  3.25  3.30  2.40  2.9  3.3  2.40
#
# [5 rows x 74 columns]

# %%
prev_results = pl_results[((pl_results['HomeTeam']=='Liverpool') & (pl_results['AwayTeam']=='Tottenham')) | ((pl_results['AwayTeam']=='Liverpool') & (pl_results['HomeTeam']=='Tottenham'))]

# %%
prev_results.head()
# Out:
#    level_0  index    AC    AF   AR    AS   AST   AY   AwayTeam  B365A  ...   \
# 0        0    137  12.0  14.0  0.0  14.0   9.0  2.0  Liverpool   2.88  ...
# 1        1    284   4.0   8.0  0.0  15.0   9.0  1.0  Tottenham   4.00  ...
# 2        2    539   9.0  15.0  0.0  21.0  10.0  0.0  Liverpool   3.00  ...
# 3        3    694   7.0   9.0  0.0  15.0   4.0  2.0  Tottenham   7.50  ...
# 4        4    789   3.0  11.0  0.0  17.0   8.0  4.0  Liverpool   2.70  ...
#
#     Referee   SJA  SJD   SJH   VCA   VCD    VCH   WHA  WHD   WHH
# 0    P Dowd  2.88  3.5  2.38  3.00  3.40   2.45  2.90  3.3  2.40
# 1  M Oliver  3.80  3.8  1.91  3.90  3.90   1.95  4.00  3.3  1.95
# 2    J Moss  2.90  3.5  2.50  2.45  2.54  37.00  2.75  3.4  2.50
# 3    P Dowd  7.50  5.0  1.44  1.45  1.50  46.00  6.50  4.5  1.44
# 4    P Dowd  2.70  3.5  2.70  2.63  2.74  49.00  2.63  3.4  2.60
#
# [5 rows x 76 columns]

# %%
prev_results = prev_results.reset_index()

# %%
prev_results = prev_results.drop(['level_0','index'],axis=1)

# %%
prev_results
# Out:
#       AC    AF   AR    AS   AST   AY   AwayTeam  B365A  B365D  B365H  ...   \
# 0   12.0  14.0  0.0  14.0   9.0  2.0  Liverpool   2.88   3.40   2.40  ...
# 1    4.0   8.0  0.0  15.0   9.0  1.0  Tottenham   4.00   3.80   1.95  ...
# 2    9.0  15.0  0.0  21.0  10.0  0.0  Liverpool   3.00   3.40   2.50  ...
# 3    7.0   9.0  0.0  15.0   4.0  2.0  Tottenham   7.50   4.75   1.48  ...
# 4    3.0  11.0  0.0  17.0   8.0  4.0  Liverpool   2.70   3.50   2.70  ...
# 5    7.0  17.0  0.0  14.0   5.0  6.0  Tottenham   4.20   3.80   1.91  ...
# 6    6.0  11.0  0.0  12.0   3.0  2.0  Liverpool   3.00   3.50   2.50  ...
# 7    9.0  11.0  0.0  18.0   5.0  0.0  Tottenham   3.00   3.40   2.50  ...
# 8    5.0  17.0  0.0  13.0   3.0  5.0  Liverpool   3.00   3.40   2.38  ...
# 9    3.0  14.0  0.0   7.0   2.0  4.0  Tottenham   3.40   3.40   2.30  ...
# 10   5.0   8.0  0.0  12.0   7.0  1.0  Liverpool   3.39   3.50   2.25  ...
# 11   7.0   9.0  0.0  13.0   6.0  1.0  Tottenham   3.60   3.75   2.10  ...
# ...

# %%
lfc
# Out:
#                        Name Nationality Position       Team   Age  Apps  \
# 0                   Alisson          br       GK  Liverpool  25.0    38
# 1           Virgil van Dijk          nl       DF  Liverpool  27.0    38
# 2             Mohamed Salah          eg    MF,FW  Liverpool  26.0    38
# 3          Andrew Robertson         sco       DF  Liverpool  24.0    36
# 4                Sadio Mané          sn    FW,MF  Liverpool  26.0    36
# 5       Georginio Wijnaldum          nl       MF  Liverpool  27.0    35
# 6           Roberto Firmino          br    FW,MF  Liverpool  26.0    34
# 7    Trent Alexander-Arnold         eng    DF,MF  Liverpool  19.0    29
# 8                   Fabinho          py       DF  Liverpool  24.0    28
# 9          Jordan Henderson          pt       MF  Liverpool  28.0    32
# 10             James Milner         eng       MF  Liverpool  32.0    31
# 11               Joël Matip          es    DF,MF  Liverpool  26.0    22
# ...

# %%
thfc
# Out:
#                       Name Nationality Position               Team   Age  \
# 0              Hugo Lloris          fr       GK  Tottenham Hotspur  31.0
# 1        Toby Alderweireld          be       DF  Tottenham Hotspur  29.0
# 2        Christian Eriksen          dk    DF,MF  Tottenham Hotspur  26.0
# 3               Harry Kane         eng       FW  Tottenham Hotspur  25.0
# 4           Moussa Sissoko          fr       MF  Tottenham Hotspur  28.0
# 5          Kieran Trippier         eng       DF  Tottenham Hotspur  27.0
# 6              Lucas Moura          br    FW,MF  Tottenham Hotspur  25.0
# 7            Son Heung-min          us    MF,FW  Tottenham Hotspur  26.0
# 8         Davinson Sánchez          ie       DF  Tottenham Hotspur  22.0
# 9           Jan Vertonghen          jm       DF  Tottenham Hotspur  31.0
# 10              Ben Davies          ch       DF  Tottenham Hotspur  25.0
# 11               Dele Alli          fr       MF  Tottenham Hotspur  22.0
# ...

# %%
positions_lfc = lfc.Position.unique()
positions_thfc = thfc.Position.unique()

# %%
pos_lfc = [None]*len(positions_lfc)
i=0
for x in positions:
    pos_lfc[i] = lfc[lfc['Position']==x]
    i = i+1
pos_thfc = [None]*len(positions_thfc)
i=0
for x in positions:
    pos_thfc[i] = lfc[lfc['Position']==x]
    i = i+1

# %%
positions_lfc
# Out:
# array(['GK', 'DF', 'MF,FW', 'FW,MF', 'MF', 'DF,MF'], dtype=object)

# %%
prev_results.columns
# Out:
# Index(['AC', 'AF', 'AR', 'AS', 'AST', 'AY', 'AwayTeam', 'B365A', 'B365D',
#        'B365H', 'BSA', 'BSD', 'BSH', 'BWA', 'BWD', 'BWH', 'Bb1X2', 'BbAH',
#        'BbAHh', 'BbAv<2.5', 'BbAv>2.5', 'BbAvA', 'BbAvAHA', 'BbAvAHH', 'BbAvD',
#        'BbAvH', 'BbMx<2.5', 'BbMx>2.5', 'BbMxA', 'BbMxAHA', 'BbMxAHH', 'BbMxD',
#        'BbMxH', 'BbOU', 'Date', 'Div', 'FTAG', 'FTHG', 'FTR', 'GBA', 'GBD',
#        'GBH', 'HC', 'HF', 'HR', 'HS', 'HST', 'HTAG', 'HTHG', 'HTR', 'HY',
#        'HomeTeam', 'IWA', 'IWD', 'IWH', 'LBA', 'LBD', 'LBH', 'PSA', 'PSCA',
#        'PSCD', 'PSCH', 'PSD', 'PSH', 'Referee', 'SJA', 'SJD', 'SJH', 'VCA',
#        'VCD', 'VCH', 'WHA', 'WHD', 'WHH'],
#       dtype='object')

# %%
lfc_away_st = prev_results['AST'].loc[prev_results['AwayTeam']=='Liverpool']
lfc_home_st = prev_results['HST'].loc[prev_results['HomeTeam']=='Liverpool']
thfc_away_st = prev_results['AST'].loc[prev_results['AwayTeam']=='Tottenham']
thfc_home_st = prev_results['HST'].loc[prev_results['HomeTeam']=='Tottenham']

# %%
lfc_st = pd.concat([lfc_home_st,lfc_away_st])
thfc_st = pd.concat([thfc_home_st,thfc_away_st])

# %%
index = range(0,len(lfc_st))
plt.figure(figsize=(15,8))
plt.plot(index,lfc_st)
plt.xlabel('index')
plt.ylabel('LFC (vs TOT) SOT')
#i = 0
#for i in range(0,19):
#    x = points[i]
#    y = players[i]
#    plt.annotate(teams[i],xy=(x,y))
# Out:
# Text(0,0.5,'LFC (vs TOT) SOT')

# %%
index1 = range(0,len(lfc_home_st))
plt.figure(figsize=(15,8))
plt.plot(index1,lfc_home_st,color='red',label='Home')
plt.xlabel('index')
plt.ylabel('SOT')
index2 = range(0,len(lfc_away_st))
plt.plot(index2,lfc_away_st,color='blue',label='Away')
plt.legend()
plt.show()

# %%
index1 = range(0,len(thfc_home_st))
plt.figure(figsize=(15,8))
plt.plot(index1,thfc_home_st,color='red',label='Home')
plt.xlabel('index')
plt.ylabel('SOT')
index2 = range(0,len(thfc_away_st))
plt.plot(index2,thfc_away_st,color='blue',label='Away')
plt.legend()
plt.show()

# %%
prev_results['Date']
# Out:
# 0       28/11/12
# 1        10/3/13
# 2       15/12/13
# 3       30/03/14
# 4       31/08/14
# 5        10/2/15
# 6       17/10/15
# 7         2/4/16
# 8       27/08/16
# 9        11/2/17
# 10      22/10/17
# 11        4/2/18
# 12      15/12/13
# 13      30/03/14
# 14      31/08/14
# 15      10/02/15
# 16      17/10/15
# 17      02/04/16
# 18      27/08/16
# 19      11/02/17
# 20      22/10/17
# 21      04/02/18
# 22    15/09/2018
# Name: Date, dtype: object

# %%
index1 = range(0,len(lfc_st))
plt.figure(figsize=(15,8))
plt.plot(index1,lfc_st,color='red',label='Liverpool')
plt.xlabel('index')
plt.ylabel('SOT')
index2 = range(0,len(thfc_st))
plt.plot(index2,thfc_st,color='blue',label='Spurs')
plt.legend()
plt.show()

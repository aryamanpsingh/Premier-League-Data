# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from bokeh.plotting import figure,output_file,show,ColumnDataSource
from bokeh.models.tools import HoverTool
import bokeh.models as bmo
from bokeh.palettes import d3
from bokeh.embed import components

# %%
lfc = pd.read_csv("Teams/Liverpool.csv")
thfc = pd.read_csv("Teams/Tottenham Hotspur.csv")

# %%
lfc
# Out:
#     Unnamed: 0                     Name Nationality Position       Team   Age  \
# 0            7                  Alisson          br       GK  Liverpool  25.0
# 1           14          Virgil van Dijk          nl       DF  Liverpool  27.0
# 2           21            Mohamed Salah          eg    MF,FW  Liverpool  26.0
# 3           27         Andrew Robertson         sco       DF  Liverpool  24.0
# 4           42               Sadio Mané          sn    FW,MF  Liverpool  26.0
# 5           82      Georginio Wijnaldum          nl       MF  Liverpool  27.0
# 6           88          Roberto Firmino          br    FW,MF  Liverpool  26.0
# 7          115   Trent Alexander-Arnold         eng    DF,MF  Liverpool  19.0
# 8          173                  Fabinho          py       DF  Liverpool  24.0
# 9          182         Jordan Henderson          pt       MF  Liverpool  28.0
# 10         205             James Milner         eng       MF  Liverpool  32.0
# ...

# %%
thfc
# Out:
#                   Name Nationality Position_x             Team_x  Age_x  Apps  \
# 20         Hugo Lloris          fr         GK  Tottenham Hotspur   31.0    33
# 21   Toby Alderweireld          be         DF  Tottenham Hotspur   29.0    34
# 22   Christian Eriksen          dk      DF,MF  Tottenham Hotspur   26.0    35
# 23          Harry Kane         eng         FW  Tottenham Hotspur   25.0    28
# 24      Moussa Sissoko          fr         MF  Tottenham Hotspur   28.0    29
# 25     Kieran Trippier         eng         DF  Tottenham Hotspur   27.0    27
# 26         Lucas Moura          br      FW,MF  Tottenham Hotspur   25.0    32
# 27    Davinson Sánchez          ie         DF  Tottenham Hotspur   22.0    23
# 28      Jan Vertonghen          jm         DF  Tottenham Hotspur   31.0    22
# 29          Ben Davies          ch         DF  Tottenham Hotspur   25.0    27
# 30           Dele Alli          fr         MF  Tottenham Hotspur   22.0    25
# ...

# %%
lfc = lfc.drop(['Unnamed: 0'],axis=1)
thfc = thfc.drop(['Unnamed: 0'],axis=1)

# %%
pl_results = pd.read_csv('pl-results-13-19.csv')

# %%
pl_results = pl_results.drop(['Unnamed: 0'],axis=1)

# %%
pl_results.head()
# Out:
#     AC    AF   AR    AS  AST   AY    AwayTeam  B365A  B365D  B365H  ...   \
# 0  0.0   8.0  0.0   3.0  2.0  0.0  Sunderland   8.50   4.50   1.40  ...
# 1  3.0  11.0  0.0   4.0  2.0  0.0     Norwich   4.50   3.60   1.80  ...
# 2  5.0   8.0  0.0  12.0  6.0  2.0   Tottenham   2.75   3.40   2.50  ...
# 3  3.0  14.0  0.0  12.0  8.0  2.0     Swansea   3.80   3.40   2.00  ...
# 4  3.0  14.0  1.0   6.0  3.0  4.0       Stoke   3.10   3.25   2.38  ...
#
#       Referee  SJA  SJD   SJH   VCA   VCD   VCH  WHA  WHD   WHH
# 0       C Foy  9.5  4.5  1.36  8.50  4.75  1.44  8.0  4.0  1.44
# 1    M Oliver  4.5  3.6  1.80  4.75  3.75  1.83  4.5  3.3  1.85
# 2  M Atkinson  2.8  3.4  2.50  2.75  3.40  2.62  2.8  3.0  2.70
# 3   L Probert  3.6  3.3  2.10  4.00  3.50  2.00  3.8  3.3  2.00
# 4    K Friend  3.0  3.2  2.40  3.25  3.30  2.40  2.9  3.3  2.40
#
# [5 rows x 74 columns]

# %%
prev_results = pl_results[((pl_results['HomeTeam']=='Liverpool') & (pl_results['AwayTeam']=='Tottenham')) | ((pl_results['AwayTeam']=='Liverpool') & (pl_results['HomeTeam']=='Tottenham'))]

# %%
prev_results.head()
# Out:
#    level_0  index    AC    AF   AR    AS   AST   AY   AwayTeam  B365A  ...   \
# 0        0    137  12.0  14.0  0.0  14.0   9.0  2.0  Liverpool   2.88  ...
# 1        1    284   4.0   8.0  0.0  15.0   9.0  1.0  Tottenham   4.00  ...
# 2        2    539   9.0  15.0  0.0  21.0  10.0  0.0  Liverpool   3.00  ...
# 3        3    694   7.0   9.0  0.0  15.0   4.0  2.0  Tottenham   7.50  ...
# 4        4    789   3.0  11.0  0.0  17.0   8.0  4.0  Liverpool   2.70  ...
#
#     Referee   SJA  SJD   SJH   VCA   VCD    VCH   WHA  WHD   WHH
# 0    P Dowd  2.88  3.5  2.38  3.00  3.40   2.45  2.90  3.3  2.40
# 1  M Oliver  3.80  3.8  1.91  3.90  3.90   1.95  4.00  3.3  1.95
# 2    J Moss  2.90  3.5  2.50  2.45  2.54  37.00  2.75  3.4  2.50
# 3    P Dowd  7.50  5.0  1.44  1.45  1.50  46.00  6.50  4.5  1.44
# 4    P Dowd  2.70  3.5  2.70  2.63  2.74  49.00  2.63  3.4  2.60
#
# [5 rows x 76 columns]

# %%
prev_results = prev_results.reset_index()

# %%
prev_results = prev_results.drop(['level_0','index'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-f38da4156c6d> in <module>()
# ----> 1 prev_results = prev_results.drop(['level_0','index'],axis=1)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# -> 3694                                            errors=errors)
#    3695
#    3696     @rewrite_axis_style_signature('mapper', [('copy', True),
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3106         for axis, labels in axes.items():
#    3107             if labels is not None:
# ...

# %%
prev_results
# Out:
#     index    AC    AF   AR    AS   AST   AY   AwayTeam  B365A  B365D  ...   \
# 0     137  12.0  14.0  0.0  14.0   9.0  2.0  Liverpool   2.88   3.40  ...
# 1     284   4.0   8.0  0.0  15.0   9.0  1.0  Tottenham   4.00   3.80  ...
# 2     539   9.0  15.0  0.0  21.0  10.0  0.0  Liverpool   3.00   3.40  ...
# 3     694   7.0   9.0  0.0  15.0   4.0  2.0  Tottenham   7.50   4.75  ...
# 4     789   3.0  11.0  0.0  17.0   8.0  4.0  Liverpool   2.70   3.50  ...
# 5    1002   7.0  17.0  0.0  14.0   5.0  6.0  Tottenham   4.20   3.80  ...
# 6    1225   6.0  11.0  0.0  12.0   3.0  2.0  Liverpool   3.00   3.50  ...
# 7    1446   9.0  11.0  0.0  18.0   5.0  0.0  Tottenham   3.00   3.40  ...
# 8    1546   5.0  17.0  0.0  13.0   3.0  5.0  Liverpool   3.00   3.40  ...
# 9    1761   3.0  14.0  0.0   7.0   2.0  4.0  Tottenham   3.40   3.40  ...
# 10   1989   5.0   8.0  0.0  12.0   7.0  1.0  Liverpool   3.39   3.50  ...
# 11   2158   7.0   9.0  0.0  13.0   6.0  1.0  Tottenham   3.60   3.75  ...
# ...

# %%
lfc
# Out:
#                       Name Nationality Position_x     Team_x  Age_x  Apps  \
# 0                  Alisson          br         GK  Liverpool   25.0    38
# 1          Virgil van Dijk          nl         DF  Liverpool   27.0    38
# 2            Mohamed Salah          eg      MF,FW  Liverpool   26.0    38
# 3         Andrew Robertson         sco         DF  Liverpool   24.0    36
# 4               Sadio Mané          sn      FW,MF  Liverpool   26.0    36
# 5      Georginio Wijnaldum          nl         MF  Liverpool   27.0    35
# 6          Roberto Firmino          br      FW,MF  Liverpool   26.0    34
# 7   Trent Alexander-Arnold         eng      DF,MF  Liverpool   19.0    29
# 8                  Fabinho          py         DF  Liverpool   24.0    28
# 9         Jordan Henderson          pt         MF  Liverpool   28.0    32
# 10            James Milner         eng         MF  Liverpool   32.0    31
# 11               Joe Gomez          be         DF  Liverpool   21.0    16
# ...

# %%
thfc.Position.unique()
# Out:
# array(['GK', 'DF', 'DF,MF', 'FW', 'MF', 'FW,MF', 'MF,FW', 'MF,DF'],
#       dtype=object)

# %%
positions_lfc = lfc.Position.unique()
positions_thfc = thfc.Position.unique()

# %%
pos_lfc = [None]*len(positions_lfc)
i=0
for x in positions_lfc:
    pos_lfc[i] = lfc[lfc['Position']==x]
    i = i+1
pos_thfc = [None]*len(positions_thfc)
i=0
for x in positions_thfc:
    pos_thfc[i] = thfc[thfc['Position']==x]
    i = i+1

# %%
positions_lfc
# Out:
# array(['GK', 'DF', 'MF,FW', 'FW,MF', 'MF', 'DF,MF'], dtype=object)

# %%
prev_results.columns
# Out:
# Index(['AC', 'AF', 'AR', 'AS', 'AST', 'AY', 'AwayTeam', 'B365A', 'B365D',
#        'B365H', 'BSA', 'BSD', 'BSH', 'BWA', 'BWD', 'BWH', 'Bb1X2', 'BbAH',
#        'BbAHh', 'BbAv<2.5', 'BbAv>2.5', 'BbAvA', 'BbAvAHA', 'BbAvAHH', 'BbAvD',
#        'BbAvH', 'BbMx<2.5', 'BbMx>2.5', 'BbMxA', 'BbMxAHA', 'BbMxAHH', 'BbMxD',
#        'BbMxH', 'BbOU', 'Date', 'Div', 'FTAG', 'FTHG', 'FTR', 'GBA', 'GBD',
#        'GBH', 'HC', 'HF', 'HR', 'HS', 'HST', 'HTAG', 'HTHG', 'HTR', 'HY',
#        'HomeTeam', 'IWA', 'IWD', 'IWH', 'LBA', 'LBD', 'LBH', 'PSA', 'PSCA',
#        'PSCD', 'PSCH', 'PSD', 'PSH', 'Referee', 'SJA', 'SJD', 'SJH', 'VCA',
#        'VCD', 'VCH', 'WHA', 'WHD', 'WHH'],
#       dtype='object')

# %%
lfc_away_st = prev_results['AST'].loc[prev_results['AwayTeam']=='Liverpool']
lfc_home_st = prev_results['HST'].loc[prev_results['HomeTeam']=='Liverpool']
thfc_away_st = prev_results['AST'].loc[prev_results['AwayTeam']=='Tottenham']
thfc_home_st = prev_results['HST'].loc[prev_results['HomeTeam']=='Tottenham']

# %%
lfc_st = pd.concat([lfc_home_st,lfc_away_st])
thfc_st = pd.concat([thfc_home_st,thfc_away_st])

# %%
index = range(0,len(lfc_st))
plt.figure(figsize=(15,8))
plt.plot(index,lfc_st)
plt.xlabel('index')
plt.ylabel('LFC (vs TOT) SOT')
#i = 0
#for i in range(0,19):
#    x = points[i]
#    y = players[i]
#    plt.annotate(teams[i],xy=(x,y))
# Out:
# Text(0,0.5,'LFC (vs TOT) SOT')

# %%
index1 = range(0,len(lfc_home_st))
plt.figure(figsize=(15,8))
plt.plot(index1,lfc_home_st,color='red',label='Home')
plt.xlabel('index')
plt.ylabel('SOT')
index2 = range(0,len(lfc_away_st))
plt.plot(index2,lfc_away_st,color='blue',label='Away')
plt.legend()
plt.show()

# %%
index1 = range(0,len(thfc_home_st))
plt.figure(figsize=(15,8))
plt.plot(index1,thfc_home_st,color='red',label='Home')
plt.xlabel('index')
plt.ylabel('SOT')
index2 = range(0,len(thfc_away_st))
plt.plot(index2,thfc_away_st,color='blue',label='Away')
plt.legend()
plt.show()

# %%
prev_results['Date']
# Out:
# 0       28/11/12
# 1        10/3/13
# 2       15/12/13
# 3       30/03/14
# 4       31/08/14
# 5        10/2/15
# 6       17/10/15
# 7         2/4/16
# 8       27/08/16
# 9        11/2/17
# 10      22/10/17
# 11        4/2/18
# 12      15/12/13
# 13      30/03/14
# 14      31/08/14
# 15      10/02/15
# 16      17/10/15
# 17      02/04/16
# 18      27/08/16
# 19      11/02/17
# 20      22/10/17
# 21      04/02/18
# 22    15/09/2018
# Name: Date, dtype: object

# %%
index1 = range(0,len(lfc_st))
plt.figure(figsize=(15,8))
plt.plot(index1,lfc_st,color='red',label='Liverpool')
plt.xlabel('index')
plt.ylabel('SOT')
index2 = range(0,len(thfc_st))
plt.plot(index2,thfc_st,color='blue',label='Spurs')
plt.legend()
plt.show()

# %%
pos_lfc[3]
# Out:
#                 Name Nationality Position       Team   Age  Apps  Starts  \
# 4         Sadio Mané          sn    FW,MF  Liverpool  26.0    36      35
# 6    Roberto Firmino          br    FW,MF  Liverpool  26.0    34      31
# 16  Daniel Sturridge          ke    FW,MF  Liverpool  28.0    18       4
# 17      Adam Lallana          es    FW,MF  Liverpool  30.0    13       5
# 18      Divock Origi          be    FW,MF  Liverpool  23.0    12       4
#
#     Subs Minutes  Min / app    ...     Yellows  Reds  SOT  Goals PG  \
# 4      1   3,086         86    ...           2     0   42      0.64
# 6      3   2,620         77    ...           0     0   35      0.41
# 16    14     496         28    ...           1     0    6      0.36
# 17     8     465         36    ...           1     0    3      0.00
# 18     8     366         31    ...           0     0    6      0.74
#
#     Goals+Asst PG  Goals no PK PG  Goals+Asst no PK PG  SOT PG  Fouls PG  \
# ...

# %%
thfc_attack = pos_thfc[3].append(pos_thfc[5])

# %%
index1 = range(0,len(lfc_attack))
plt.figure(figsize=(10,5))
plt.bar(lfc_attack.Name,lfc_attack.SOT,color='red',label='SOT')
plt.xlabel('index')
plt.ylabel('SOT')

plt.bar(lfc_attack.Name,lfc_attack.Goals,color='green',label='Goals')
plt.legend()
plt.show()

# %%
index1 = range(0,len(thfc_attack))
plt.figure(figsize=(10,5))
plt.bar(thfc_attack.Name,thfc_attack.SOT,color='red',label='SOT')
plt.xlabel('index')
plt.ylabel('SOT')

plt.bar(thfc_attack.Name,thfc_attack.Goals,color='green',label='Goals')
plt.legend()
plt.show()

# %%
pos_thfc[2]
# Out:
#              Name Nationality Position               Team   Age  Apps  Starts  \
# 7   Son Heung-min          us    MF,FW  Tottenham Hotspur  26.0    31      23
# 15    Érik Lamela          be    MF,FW  Tottenham Hotspur  26.0    19       9
#
#     Subs Minutes  Min / app    ...     Yellows  Reds  SOT  Goals PG  \
# 7      8   2,047         66    ...           2     1   29      0.53
# 15    10     972         51    ...           2     0   11      0.37
#
#     Goals+Asst PG  Goals no PK PG  Goals+Asst no PK PG  SOT PG  Fouls PG  \
# 7            0.79            0.53                 0.79    1.28      0.48
# 15           0.56            0.37                 0.56    1.02      2.13
#
#     Cards PG
# 7       0.48
# 15      2.13
#
# [2 rows x 25 columns]

# %%
pos_thfc[6]
# Out:
#              Name Nationality Position               Team   Age  Apps  Starts  \
# 7   Son Heung-min          us    MF,FW  Tottenham Hotspur  26.0    31      23
# 15    Érik Lamela          be    MF,FW  Tottenham Hotspur  26.0    19       9
#
#     Subs Minutes  Min / app    ...     Yellows  Reds  SOT  Goals PG  \
# 7      8   2,047         66    ...           2     1   29      0.53
# 15    10     972         51    ...           2     0   11      0.37
#
#     Goals+Asst PG  Goals no PK PG  Goals+Asst no PK PG  SOT PG  Fouls PG  \
# 7            0.79            0.53                 0.79    1.28      0.48
# 15           0.56            0.37                 0.56    1.02      2.13
#
#     Cards PG
# 7       0.48
# 15      2.13
#
# [2 rows x 25 columns]

# %%
index1 = range(0,len(thfc_attack))
plt.figure(figsize=(12,8))
sns.set_style('darkgrid')
sns.barplot(thfc_attack.Name,thfc_attack.SOT,color='yellow',label='SOT')

sns.barplot(thfc_attack.Name,thfc_attack.Goals,color='black',label='Goals')\

# %%
df = pd.concat([lfc,thfc])

# %%
df = df.reset_index()

# %%
df['Goals+Assists'] = df['Goals'].add(df['Assists'])

# %%
df
# Out:
#     index                     Name Nationality Position               Team  \
# 0       0                  Alisson          br       GK          Liverpool
# 1       1          Virgil van Dijk          nl       DF          Liverpool
# 2       2            Mohamed Salah          eg    MF,FW          Liverpool
# 3       3         Andrew Robertson         sco       DF          Liverpool
# 4       4               Sadio Mané          sn    FW,MF          Liverpool
# 5       5      Georginio Wijnaldum          nl       MF          Liverpool
# 6       6          Roberto Firmino          br    FW,MF          Liverpool
# 7       7   Trent Alexander-Arnold         eng    DF,MF          Liverpool
# 8       8                  Fabinho          py       DF          Liverpool
# 9       9         Jordan Henderson          pt       MF          Liverpool
# 10     10             James Milner         eng       MF          Liverpool
# ...

# %%
plt.figure(figsize=(15,5))
sns.set_style("whitegrid")
plt.figure(figsize=(20,10))
sns.lmplot(x='Apps',y='Goals+Assists',data=df, hue='Team', fit_reg=False, markers='+')

# %%
lfc['Goals+Assists'] = lfc['Goals'].add(lfc['Assists'])
thfc['Goals+Assists'] = thfc['Goals'].add(thfc['Assists'])

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data=lfc)

# %%
plt.figure(figsize=(20,10))
sns.boxplot(data=thfc)

# %%
plt.figure(figsize=(50,10))
sns.boxplot(data=prev_results)

# %%
sns.violinplot(x='Position',y='Goals+Assists',data=lfc)
plt.xlim(0,None)
plt.ylim(0,None)
# Out:
# (0, 40.43436522555715)

# %%
lfc.query('Name == "Mohamed Salah"').Position = "FW,MF"
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
lfc.query('Name == "Mohamed Salah"').Position
# Out:
# 2    MF,FW
# Name: Position, dtype: object

# %%
ws = pd.read_csv('ws_stats.csv')

# %%
ws.loc[26]['Name'] = 'lol'
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
new = ws['Name'].str.split("\n", expand=True)
new_1 = new[1].str.split(",", n=1, expand=True)

# %%
ws['Name'] = new[0]

# %%
ws['Age'] = new_1[0]
ws['Position'] = new_1[1]

# %%
df = df.merge(ws.set_index('Name'), on='Name')

# %%
df
# Out:
#     index                     Name Nationality  Apps  Starts  Subs Minutes  \
# 0       0                  Alisson          br    38      38     0   3,420
# 1       1          Virgil van Dijk          nl    38      38     0   3,385
# 2       2            Mohamed Salah          eg    38      37     1   3,262
# 3       3         Andrew Robertson         sco    36      36     0   3,219
# 4       4               Sadio Mané          sn    36      35     1   3,086
# 5       5      Georginio Wijnaldum          nl    35      32     3   2,736
# 6       6          Roberto Firmino          br    34      31     3   2,620
# 7       7   Trent Alexander-Arnold         eng    29      27     2   2,467
# 8       8                  Fabinho          py    28      21     7   2,013
# 9       9         Jordan Henderson          pt    32      21    11   1,981
# 10     10             James Milner         eng    31      19    12   1,785
# ...

# %%
df = df.replace('-',0)

# %%
df.shape
# Out:
# (51, 32)

# %%
lfc = df[df['Team_x']=='Liverpool']
thfc = df[df['Team_x']=='Tottenham Hotspur']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Team_x'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-475-aef9b9c63466> in <module>()
# ...

# %%
df['Team']=df['Team_x']
df['Position']=df['Position_x']
df['Age']=df['Age_x']
df = df.drop(['Team_y', 'Team_x', 'Position_x', 'Age_x'], axis=1)

# %%
sns.lmplot(x='Minutes',y='Rating',hue='Team',data=df,fit_reg=False)

# %%
plt.figure(figsize=(15,10))
sns.lmplot(x='Minutes',y='Rating',hue='Position_x',data=lfc,fit_reg=False)
plt.xlim(250,3500)
plt.ylim(6,7.6)
sns.lmplot(x='Minutes',y='Rating',hue='Position_x',data=thfc,fit_reg=False)
plt.xlim(250,3500)
plt.ylim(6,7.6)
# Out:
# (6, 7.6)

# %%
lfc.shape
# Out:
# (23, 25)

# %%
ws = ws.replace('Alex Oxlade Chamberlain','Alex Oxlade-Chamberlain')
ws = ws.replace('Son Heung-Min','Son Heung-min')
ws = ws.replace("Georges-Kévin Nkoudou","Georges-Kévin N'Koudou")
ws = ws.replace("Joel Matip","Joël Matip")
ws = ws.replace("Naby Keita","Naby Keïta")
ws = ws.replace("Erik Lamela","Érik Lamela")

# %%
attack = df[df['Position'].str.contains("FW")]
defence = df[df['Position'].str.contains("DF")]

# %%
plt.figure(figsize=(15,8))
sns.lmplot(data=attack, x='Minutes', y='Goals+Asst no PK PG', hue='Team',fit_reg=False)

# %%
plt.figure(figsize=(15,8))
sns.lmplot(data=defence, x='Minutes', y='Aerials won', hue='Team')

# %%
defence['Aerials won'] = defence['Aerials won'].astype('float')
df['Aerials won'] = df['Aerials won'].astype('float')
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
plt.figure(figsize=(15,8))
sns.barplot(data=defence, x='Name', y='Aerials won', hue='Team')

# %%
plt.figure(figsize=(15,8))
sns.boxplot(data=df_pg)

# %%
df_pg = df[['Name','Team','Goals PG', 'Goals+Asst PG',
       'Goals no PK PG', 'Goals+Asst no PK PG', 'SOT PG', 'Fouls PG',
       'Cards PG']]
name_list = defence['Name'].tolist()

# %%
df.to_csv('final_df.csv')

# %%
#Add CDS
source = ColumnDataSource(df)
def_src = ColumnDataSource(defence)

# %%
#Add figure
p = figure (y_range = name_list, title = 'Aerieal Threats', y_axis_label = 'Aerials Won PG')

#Configure color mapping
palette = d3['Category10'][4]
color_map = bmo.CategoricalColorMapper(factors=df['Team'].unique(),
                                   palette=palette)
#Add hover tools
hover = HoverTool()
hover.tooltips = """
    <div>
        <h3>@Name</h3>
        <div>@{Aerials won}</div>
        <div>@Team</div>
        <div><img src=@Image width=75 /></div>
    </div>
    """
p.add_tools(hover)

#Add hbar plot
p.hbar (y = 'Name', right = 'Aerials won', left = 0, source = def_src, height = 0.75, color = {'field': 'Team', 'transform': color_map}, fill_alpha=0.8, legend='Team')

#Add legend
p.legend.orientation = 'vertical'
p.legend.label_text_font_size = '10px'

output_file('aerial.html')

# %%
show(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: 0.4 [renderer: GlyphRenderer(id='98179cce-a746-4798-87ce-a25ba5b53ab7', ...)]

# %%
palette = d3['Category10'][len(df['cat'].unique())]
color_map = bmo.CategoricalColorMapper(factors=df['cat'].unique(),
                                   palette=palette)
# Out:
# 0     0.3
# 1     4.8
# 2     0.3
# 3     0.7
# 4     1.0
# 5     0.9
# 6     0.9
# 7     0.3
# 8     2.0
# 9     0.8
# 10    0.6
# 11    3.0
# 12    0.4
# 13    1.5
# 14    0.1
# 15    4.1
# 16    0.2
# 17    0.7
# 18    0.3
# 19    0.0
# 20    0.3
# 21    0.0
# 22    0.0
# 23    0.3
# 24    1.6
# 25    0.4
# 26    1.8
# 27    0.8
# 28    1.1
# 29    1.1
# 30    0.1
# 31    2.9
# 32    2.3
# 33    1.7
# 34    0.8
# 35    1.0
# 36    0.5
# 37    1.8
# 38    0.2
# 39    2.1
# 40    2.7
# 41    1.5
# 42    0.6
# 43    1.1
# 44    0.5
# 45    0.0
# 46    1.3
# 47    0.5
# 48    1.0
# 49    0.0
# 50    1.0
# Name: Aerials won, dtype: float64

# %%
df['Image'] = ['img/lfc/alisson.png','img/lfc/vvd.png','img/lfc/salah.png','img/lfc/robertson.png','img/lfc/mane.png','img/lfc/gini.png','img/lfc/firmino.png','img/lfc/taa.png','img/lfc/fabinho.png','img/lfc/henderson.png','img/lfc/milner.png','img/lfc/matip.png','img/lfc/keita.png','img/lfc/gomez.png','img/lfc/shaqiri.png','img/lfc/lovren.png','img/lfc/sturridge.png','img/lfc/lallana.png','img/lfc/origi.png','img/lfc/moreno.png','img/lfc/clyne.png','img/lfc/ox.png','img/lfc/camacho.png','img/thfc/lloris.png','img/thfc/toby.png','img/thfc/eriksen.png','img/thfc/kane.png','img/thfc/sissoko.png','img/thfc/trippier.png','img/thfc/moura.png','img/thfc/son.png','img/thfc/sanchez.png','img/thfc/vertonghen.png','img/thfc/davies.png','img/thfc/alli.png','img/thfc/rose.png','img/thfc/winks.png','img/thfc/dier.png','img/thfc/lamela.png','img/thfc/foyth.png','/img/thfc/llorente.png','/img/thfc/aurier.png','img/thfc/dembele.png','img/thfc/wanyama.png','img/thfc/walkers-peters.png','img/thfc/gazza.png','img/thfc/skipp.png','img/thfc/worm.png','img/thfc/janssen.png','img/thfc/amo.png','img/thfc/amos.png']

# %%
attack = df[df['Position'].str.contains("FW")]
defence = df[df['Position'].str.contains("DF")]

# %%
#Test generate script to embed
def_src2 = ColumnDataSource(defence)
#Add figure
p2 = figure (y_range = name_list, title = 'Aerieal Threats', y_axis_label = 'Aerials Won PG')

#Configure color mapping
palette2 = d3['Category10'][4]
color_map2 = bmo.CategoricalColorMapper(factors=df['Team'].unique(),
                                   palette=palette2)
#Add hover tools
hover2 = HoverTool()
hover2.tooltips = """
    <div>
        <h3>@Name</h3>
        <div>@{Aerials won}</div>
        <div>@Team</div>
        <div><img src=@Image width=75 /></div>
    </div>
    """
p2.add_tools(hover2)

#Add hbar plot
p2.hbar (y = 'Name', right = 'Aerials won', left = 0, source = def_src2, height = 0.75, color = {'field': 'Team', 'transform': color_map2}, fill_alpha=0.8, legend='Team')

#Add legend
p2.legend.orientation = 'vertical'
p2.legend.label_text_font_size = '10px'

script, div = components(p2)

# %%
print(script)
# Out:
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
# ...

# %%
print(div)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="567486f6-880d-4298-8c9e-5b075d084b4a"></div>
# </div>

# %%
df.head()
# Out:
#    index              Name Nationality  Apps  Starts  Subs Minutes  Min / app  \
# 0      0           Alisson          br    38      38     0   3,420         90
# 1      1   Virgil van Dijk          nl    38      38     0   3,385         89
# 2      2     Mohamed Salah          eg    38      37     1   3,262         86
# 3      3  Andrew Robertson         sco    36      36     0   3,219         89
# 4      4        Sadio Mané          sn    36      35     1   3,086         86
#
#    Goals_x  Assists_x          ...            Goals+Assists  Height  \
# 0        0          0          ...                        0     191
# 1        4          2          ...                        6     193
# 2       22          8          ...                       30     175
# 3        0         11          ...                       11     178
# 4       22          1          ...                       23     175
#
#    Pass Accuracy  Aerials won  MOTMs  Rating       Team  Position   Age  \
# ...

# %%
df = df.drop(df[df.Apps<5].index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-5be8fae57586> in <module>()
# ----> 1 df.drop(df[df.Minutes.astype('int')<500].index)
#
# /anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     175                 else:
#     176                     kwargs[new_arg_name] = new_arg_value
# --> 177             return func(*args, **kwargs)
#     178         return wrapper
#     179     return _deprecate_kwarg
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4995             # else, only a single dtype is given
#    4996             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4997                                          **kwargs)
#    4998             return self._constructor(new_data).__finalize__(self)
#    4999
#
# ...

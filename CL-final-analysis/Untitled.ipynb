# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from bokeh.plotting import figure,output_file,show,ColumnDataSource,show
from bokeh.models.tools import HoverTool
import bokeh.models as bmo
from bokeh.palettes import d3
from bokeh.embed import components

# %%
df = pd.read_csv('final_df.csv')

# %%
df
# Out:
#     Unnamed: 0  index                     Name Nationality  Apps  Starts  \
# 0            0      0                  Alisson          br    38      38
# 1            1      1          Virgil van Dijk          nl    38      38
# 2            2      2            Mohamed Salah          eg    38      37
# 3            3      3         Andrew Robertson         sco    36      36
# 4            4      4               Sadio Mané          sn    36      35
# 5            5      5      Georginio Wijnaldum          nl    35      32
# 6            6      6          Roberto Firmino          br    34      31
# 7            7      7   Trent Alexander-Arnold         eng    29      27
# 8            8      8                  Fabinho          py    28      21
# 9            9      9         Jordan Henderson          pt    32      21
# 10          10     10             James Milner         eng    31      19
# 11          11     11               Joël Matip          es    22      17
# ...

# %%
attack = xf[xf['Position'].str.contains("FW")]
defence = xf[xf['Position'].str.contains("DF")]
midfield = xf[xf['Position'].str.contains("MF") & (xf['Position'].str.contains("FW")==False)]

# %%
source = ColumnDataSource(attack)
name_list = attack['Name'].tolist()
#Add figure
p = figure (x_range = name_list, title = 'Match Winners', x_axis_label = 'MOTM Awards')

#Configure color mapping
palette = d3['Category10'][4]
color_map = bmo.CategoricalColorMapper(factors=df['Team'].unique(),
                                   palette=palette)
#Add hover tools
hover = HoverTool()
hover.tooltips = """
    <div>
        <h4>@Name</h4>
        <div>MOTMs : @{MOTMs}</div>
        <div>@Team</div>
        <div><img src=@Image width=75 /></div>
    </div>
    """
p.add_tools(hover)

#Add hbar plot
p.vbar (x = 'Name', top = 'MOTMs', bottom = 0, source = source, width = 0.75, color = {'field': 'Team', 'transform': color_map}, fill_alpha=0.8, legend='Team')

#Add legend
p.legend.orientation = 'vertical'
p.legend.label_text_font_size = '10px'

script, div = components(p)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Team [renderer: GlyphRenderer(id='7b82304b-b9a6-4c7c-be7e-6c81c12709b5', ...)]

# %%
print(script)
# Out:
# <script type="text/javascript">
#   (function() {
#     var fn = function() {
#       Bokeh.safely(function() {
#         (function(root) {
#           function embed_document(root) {
#
# ...

# %%
print(div)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="97b850e7-bdc4-477c-9d9d-4c68c1b82729"></div>
# </div>

# %%
source_2 = ColumnDataSource(attack)
name_list = attack['Name'].tolist()
#Add figure
p_attack_1 = figure (y_range = name_list, title = 'XG per 90', y_axis_label = 'xg90')

#Configure color mapping
palette = d3['Category10'][4]
color_map = bmo.CategoricalColorMapper(factors=xf['Team_x'].unique(),
                                   palette=palette)
#Add hover tools
hover_2 = HoverTool()
hover_2.tooltips = """
    <div>
        <h4>@Name</h4>
        <div>G+A : @{xG}</div>
        <div>@Team_x</div>
        <div><img src=@Image width=75 /></div>
    </div>
    """
p_attack_1.add_tools(hover_2)

#Add hbar plot
p_attack_1.hbar (y = 'Name', right = 'xG', left = 0, source = source_2, height = 0.75, color = {'field': 'Team_x', 'transform': color_map}, fill_alpha=0.8, legend='Team_x')

#Add legend
p_attack_1.legend.orientation = 'vertical'
p_attack_1.legend.label_text_font_size = '10px'

script, div = components(p)
output_file('ga.html')
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Team [renderer: GlyphRenderer(id='7b82304b-b9a6-4c7c-be7e-6c81c12709b5', ...)]

# %%
show(p_attack_1)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='d622a0b0-07f4-4770-955c-5e6bf58bad97', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='03520738-94e1-4a98-bda0-b6ed1192f3ab', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='293cda43-94bf-4e9b-b489-48b3076e39b8', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Assists [renderer: GlyphRenderer(id='daa76d90-91c5-46a6-a69f-be7e39d16af5', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: xG [renderer: GlyphRenderer(id='cfbc92e6-e83a-4fdb-ab9a-90bf8444e151', ...)]
# ...

# %%
attack
# Out:
#     Unnamed: 0  index               Name Nationality  Apps  Starts  Subs  \
# 2            2      2      Mohamed Salah          eg    38      37     1
# 4            4      4         Sadio Mané          sn    36      35     1
# 6            6      6    Roberto Firmino          br    34      31     3
# 16          16     16   Daniel Sturridge          ke    18       4    14
# 17          17     17       Adam Lallana          es    13       5     8
# 18          18     18       Divock Origi          be    12       4     8
# 26          26      3         Harry Kane         eng    28      27     1
# 29          29      6        Lucas Moura          br    32      25     7
# 30          30      7      Son Heung-min          us    31      23     8
# 38          38     15        Érik Lamela          be    19       9    10
# 40          40     17  Fernando Llorente         eng    20       6    14
#
#    Minutes  Min / app  Goals_x           ...            Goals+Assists  Height  \
# ...

# %%
source_2 = ColumnDataSource(attack)
name_list = attack['Name'].tolist()
goals_list = attack['Goals+Assists'].tolist()
#Add figure
p_attack_1 = figure (title = 'Most Goals + Assists', y_axis_label = 'Goals + Assists', tools = 'box_select,zoom_in,zoom_out,save,reset')

#Configure color mapping
palette = d3['Category10'][4]
color_map = bmo.CategoricalColorMapper(factors=df['Team'].unique(),
                                   palette=palette)
#Add hover tools
hover_2 = HoverTool()
hover_2.tooltips = """
    <div>
        <h4>@Name</h4>
        <div>G+A : @{Goals+Assists}</div>
        <div>@Team</div>
        <div><img src=@Image width=75 /></div>
    </div>
    """
p_attack_1.add_tools(hover_2)

#Add hbar plot
p_attack_1.hex ('Goals+Assists','Aerials won', source = source_2, size=15, color = {'field': 'Team', 'transform': color_map}, fill_alpha=0.8, legend='Team')

#Add legend
p_attack_1.legend.orientation = 'vertical'
p_attack_1.legend.label_text_font_size = '10px'

output_file('ga.html')

# %%
midfield
# Out:
#     Unnamed: 0  index                     Name Nationality  Apps  Starts  \
# 2            2      2            Mohamed Salah          eg    38      37
# 4            4      4               Sadio Mané          sn    36      35
# 5            5      5      Georginio Wijnaldum          nl    35      32
# 6            6      6          Roberto Firmino          br    34      31
# 7            7      7   Trent Alexander-Arnold         eng    29      27
# 9            9      9         Jordan Henderson          pt    32      21
# 10          10     10             James Milner         eng    31      19
# 11          11     11               Joël Matip          es    22      17
# 12          12     12               Naby Keïta          es    25      16
# 14          14     14          Xherdan Shaqiri         eng    24      11
# 16          16     16         Daniel Sturridge          ke    18       4
# 17          17     17             Adam Lallana          es    13       5
# ...

# %%
source_3 = ColumnDataSource(midfield)
name_list = attack['Name'].tolist()
goals_list = attack['Goals+Assists'].tolist()
#Add figure
p_midfield_1 = figure (title = 'Midfield comparison', x_axis_label = 'Assists', y_axis_label = 'Pass Accuracy',tools = 'box_select,zoom_in,zoom_out,save,reset')

#Configure color mapping
palette = d3['Category10'][4]
color_map = bmo.CategoricalColorMapper(factors=df['Team'].unique(),
                                   palette=palette)
#Add hover tools
hover_2 = HoverTool()
hover_2.tooltips = """
    <div>
        <h4>@Name</h4>
        <div>G+A : @{Assists_x}</div>
        <div>Pass% : @{Pass Accuracy}</div>
        <div>@Team</div>
        <div><img src=@Image width=75 /></div>
    </div>
    """
p_midfield_1.add_tools(hover_2)

#Add hbar plot
p_midfield_1.hex ('Assists_x','Pass Accuracy', source = source_3, size=15, color = {'field': 'Team', 'transform': color_map}, fill_alpha=0.8, legend='Team')

#Add legend
p_midfield_1.legend.orientation = 'vertical'
p_midfield_1.legend.label_text_font_size = '10px'

output_file('ga2.html')

# %%
show(p_midfield_1)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='d622a0b0-07f4-4770-955c-5e6bf58bad97', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='03520738-94e1-4a98-bda0-b6ed1192f3ab', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='293cda43-94bf-4e9b-b489-48b3076e39b8', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Assists [renderer: GlyphRenderer(id='daa76d90-91c5-46a6-a69f-be7e39d16af5', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: xG [renderer: GlyphRenderer(id='cfbc92e6-e83a-4fdb-ab9a-90bf8444e151', ...)]
# ...

# %%
x_final = pd.read_csv('x_final.csv')

# %%
x_final = x_final.merge(df.set_index('Name'), on='Name')

# %%
x_final
# Out:
#     Unnamed: 0_x                     Name     Team_x          xG          xA  \
# 0              1               Sadio Mané  Liverpool  16.76-5.24   5.12+4.12
# 1              2            Mohamed Salah  Liverpool  21.79-0.21  10.47+2.47
# 2             17          Roberto Firmino  Liverpool  13.74+1.74   6.34+0.34
# 3             55          Xherdan Shaqiri  Liverpool   4.06-1.94   1.89-1.11
# 4             58             James Milner  Liverpool   3.36-1.64   5.64+1.64
# 5             82          Virgil van Dijk  Liverpool   3.51-0.49   1.27-0.73
# 6             92             Divock Origi  Liverpool   2.24-0.76   0.19-0.81
# 7            104      Georginio Wijnaldum  Liverpool   3.18+0.18   1.94+1.94
# 8            129         Daniel Sturridge  Liverpool   1.50-0.50   1.07+0.07
# 9            151               Naby Keïta  Liverpool   2.55+0.55   1.07+0.07
# 10           164               Joël Matip  Liverpool   0.90-0.10   0.18+0.18
# ...

# %%
x_final = x_final.replace('Joel Matip','Joël Matip')
x_final = x_final.replace('Naby Keita','Naby Keïta')
x_final = x_final.replace("Joseph Gomez","Joe Gomez")
x_final = x_final.replace("Son Heung-Min","Son Heung-min")
x_final = x_final.replace("Erik Lamela","Érik Lamela")

# %%
x_final = x_final.drop(x_final[x_final.index==48].index)

# %%
xf = x_final

# %%
xf
# Out:
#     Unnamed: 0_x                     Name     Team_x     xG     xA  xG90  \
# 0              1               Sadio Mané  Liverpool  16.76   5.12  0.49
# 1              2            Mohamed Salah  Liverpool  21.79  10.47  0.60
# 2             17          Roberto Firmino  Liverpool  13.74   6.34  0.47
# 3             55          Xherdan Shaqiri  Liverpool   4.06   1.89  0.35
# 4             58             James Milner  Liverpool   3.36   5.64  0.17
# 5             82          Virgil van Dijk  Liverpool   3.51   1.27  0.09
# 6             92             Divock Origi  Liverpool   2.24   0.19  0.57
# 7            104      Georginio Wijnaldum  Liverpool   3.18   1.94  0.10
# 8            129         Daniel Sturridge  Liverpool   1.50   1.07  0.28
# 9            151               Naby Keïta  Liverpool   2.55   1.07  0.16
# 10           164               Joël Matip  Liverpool   0.90   0.18  0.05
# 11           182             Dejan Lovren  Liverpool   0.91   0.11  0.08
# ...

# %%
ng = xf['xG'].str.split("-", expand=True, n=1)
na = xf['xA'].str.split("-", expand=True, n=1)

xf['xG'] = ng
xf['xA'] = na

# %%
attack.columns
# Out:
# Index(['Unnamed: 0_x', 'Name', 'Team_x', 'xG', 'xA', 'xG90', 'xA90',
#        'Unnamed: 0_y', 'index', 'Nationality', 'Apps', 'Starts', 'Subs',
#        'Minutes', 'Min / app', 'Goals_x', 'Assists_x', 'PK', 'PKAtt', 'Fouls',
#        'Yellows', 'Reds', 'SOT', 'Goals PG', 'Goals+Asst PG', 'Goals no PK PG',
#        'Goals+Asst no PK PG', 'SOT PG', 'Fouls PG', 'Cards PG',
#        'Goals+Assists', 'Height', 'Pass Accuracy', 'Aerials won', 'MOTMs',
#        'Rating', 'Team_y', 'Position', 'Age', 'Image'],
#       dtype='object')

# %%
source_4 = ColumnDataSource(attack)
name_list = attack['Name'].tolist()
goals_list = attack['Goals+Assists'].tolist()
#Add figure
p_attack_2 = figure (y_range = name_list, title = 'XG vs SOT', x_axis_label = 'SOT', y_axis_label = 'XG',tools = 'box_select,zoom_in,zoom_out,save,reset')

#Configure color mapping
palette = d3['Category10'][4]
color_map = bmo.CategoricalColorMapper(factors=attack['Team_x'].unique(),
                                   palette=palette)
#Add hover tools
hover_3 = HoverTool()
hover_3.tooltips = """
    <div>
        <h4>@Name</h4>
        <div>G+A : @{Assists_x}</div>
        <div>Pass% : @{Pass Accuracy}</div>
        <div>@Team</div>
        <div><img src=@Image width=75 /></div>
    </div>
    """
p_attack_2.add_tools(hover_2)

#Add hbar plot
p_attack_2.hex ('SOT','xG', source = source_4, size=15, color = {'field': 'Team_x', 'transform': color_map}, fill_alpha=0.8, legend='Team')

#Add legend
p_attack_2.legend.orientation = 'vertical'
p_attack_2.legend.label_text_font_size = '10px'

output_file('ga3.html')

# %%
show(p_attack_2)
# Out:
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='d622a0b0-07f4-4770-955c-5e6bf58bad97', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='03520738-94e1-4a98-bda0-b6ed1192f3ab', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Aerials Won [renderer: GlyphRenderer(id='293cda43-94bf-4e9b-b489-48b3076e39b8', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: Assists [renderer: GlyphRenderer(id='daa76d90-91c5-46a6-a69f-be7e39d16af5', ...)]
# ERROR:bokeh.core.validation.check:E-1001 (BAD_COLUMN_NAME): Glyph refers to nonexistent column name: xG [renderer: GlyphRenderer(id='cfbc92e6-e83a-4fdb-ab9a-90bf8444e151', ...)]
# ...

# %%
xf.to_csv("xf.csv")

# %%
attack.to_csv("attack.csv")
midfield.to_csv("midfield.csv")
defence.to_csv("defence.csv")

# %%
attack['SOT']
# Out:
# 0     42
# 1     64
# 2     35
# 6      6
# 8      6
# 14     3
# 18    46
# 19    29
# 20    20
# 23    11
# 29     5
# Name: SOT, dtype: int64

# %%
defence = defence.drop([14,24,27])

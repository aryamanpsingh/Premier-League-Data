# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np

# %%
stats = pd.read_csv('prem-stats.csv')

# %%
table = pd.read_csv('prem-table1819.csv')

# %%
df = pd.read_csv('prem-data2.csv')

# %%
df = df.drop(['Unnamed: 0'],axis=1)

# %%
df.to_csv('prem-data2.csv')

# %%
teams = df['Team Name'].values
teams_top6 = top_6['Team Name'].values
teams_rest = rest['Team Name'].values

# %%
top_6 = df.loc[:5]
rest = df.loc[6:]

# %%
sot_top6 = top_6['Shots on Target'].values
sot_rest = rest['Shots on Target'].values

# %%
plt.figure(figsize=(25,10))
plt.bar(teams_top6,sot_top6,color='red')
plt.bar(teams_rest,sot_rest,color='green')
plt.title('Shots on Target - Top 6 vs Rest')
# Out:
# Text(0.5,1,'Shots on Target - Top 6 vs Rest')

# %%
plt.figure(figsize=(25,10))
fouls_top6 = top_6['Fouls'].values
fouls_rest = rest['Fouls'].values
plt.bar(teams_top6,fouls_top6,color='red')
plt.bar(teams_rest,fouls_rest,color='green')
# Out:
# <BarContainer object of 14 artists>

# %%
fouls = df['Fouls']
ga = df['GA']
yellows = df['Yellow Cards']
reds = df['Red Cards']
players = df['Players Used']
points = df['Points']

# %%
plt.figure(figsize=(15,5))
plt.scatter(fouls,ga)
plt.xlabel('Fouls')
plt.ylabel('GA')
# Out:
# Text(0,0.5,'GA')

# %%
plt.figure(figsize=(15,5))
plt.bar(teams,fouls,color="green",label="Fouls")
plt.bar(teams,yellows,color="yellow",bottom=reds,label="Yellows")
plt.bar(teams,reds,color="red",label="Reds")
plt.ylabel('Fouls')
plt.legend()

# %%
plt.figure(figsize=(15,8))
plt.plot(points,players)
plt.xlabel('Points')
plt.ylabel('Players Used')
i = 0
for i in range(0,19):
    x = points[i]
    y = players[i]
    plt.annotate(teams[i],xy=(x,y))

# %%
players[4]
# Out:
# 28

# %%
pk_won = df['PK Won'].values
pk_scored = df['PK Scored'].values
pk_missed = pk_won-pk_scored

# %%
plt.figure(figsize=(15,7))
plt.bar(teams,pk_missed,color='red',label='Penalties Missed',bottom=pk_scored)
plt.bar(teams,pk_scored,color='green',label='Penalties Scored')
plt.legend()
